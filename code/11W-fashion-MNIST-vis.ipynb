# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(512, activation='relu'),
                          keras.layers.Dense(256, activation='relu'),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(10, activation='softmax'),
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7031d8e488ad> in <module>()
# ----> 1 model = keras.Sequential([
#       2                           keras.layers.Flatten(input_shape=(28,28)),
#       3                           keras.layers.Dense(512, activation='relu'),
#       4                           keras.layers.Dense(256, activation='relu'),
#       5                           keras.layers.Dense(128, activation='relu'),
#
# NameError: name 'keras' is not defined

# %%
model.fit(train_images, train_labels, epochs=8)

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\n 테스트 정확도:', test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7ea4290eb679> in <module>()
# ----> 1 model.fit(train_images, train_labels, epochs=8)
#       2
#       3 test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
#       4 print('\n 테스트 정확도:', test_acc)
#
# NameError: name 'model' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %%
fashion_mnist = keras.datasets.fashion_mnist(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
#   File "<ipython-input-5-93d5362e2305>", line 1
#     fashion_mnist = keras.datasets.fashion_mnist(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
#                    ^
# SyntaxError: can't assign to function call

# %%
train_images.shape, test_images.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1f0d3970c1ac> in <module>()
# ----> 1 train_images.shape, test_images.shape
#
# NameError: name 'train_images' is not defined

# %%
train_labels.shape, test_labels.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4be00f3e10d9> in <module>()
# ----> 1 train_labels.shape, test_labels.shape
#
# NameError: name 'train_labels' is not defined

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover','Dress','Coat', 'Sandal','Shirt','Sneaker','Bga','Ankie boot']

# %%
print(train_labels[0])
print(class_names[train_labels[0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e65aef5ea8b9> in <module>()
# ----> 1 print(train_labels[0])
#       2 print(class_names[train_labels[0]])
#
# NameError: name 'train_labels' is not defined

# %%
plt.figure()
plt.imshow(train_-images[0])
plt.title('index:0, ' + class_names[train_labels[0]])
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-dfa69f182e52> in <module>()
#       1 plt.figure()
# ----> 2 plt.imshow(train_-images[0])
#       3 plt.title('index:0, ' + class_names[train_labels[0]])
#       4 plt.colorbar()
#       5 plt.show()
#
# NameError: name 'train_' is not defined

# %%
plt.figure(figsize = (10,6))

plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

plt.show()

# %%
plt.figure(figsize = (10,6))

plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,1,2)

plt.show()

# %%
plt.figure(figsize = (10,6))

plt.subplot(411)
plt.subplot(423)
plt.subplot(424)
plt.subplot(425)
plt.subplot(426)
plt.subplot(414)
plt.show()

# %%
import numpy as np

x= np.arange(0, 5, 0.01)

plt.figure(figsize=(10,12))

plt.subplot(411)
plt.plot(x, np.sqrt(x))
plt.grid()

plt.subplot(423)
plt.plot(x, x**2)
plt.grid()

plt.subplot(424)
plt.plot(x, x**3)
plt.grid()

plt.subplot(411)
plt.plot(x, np.sin(x))
plt.grid()

plt.subplot(411)
plt.plot(x, np.cos(x))
plt.grid()

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.figure(figsize=(12,10))
for i in range(30):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[i], cmap = plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5009fb1f18ed> in <module>()
#       4   plt.xticks([])
#       5   plt.yticks([])
# ----> 6   plt.imshow(train_images[i], cmap = plt.cm.binary)
#       7   plt.xlabel(class_names[train_labels[i]])
#       8
#
# NameError: name 'train_images' is not defined

# %%
from random import sample

rows, cols = 5,6
idx = sorted(sample(range(len(train_images)), rows * cols)) #출력할 첨자 선정
print(idx)

cnt = 0
plt.figure(figsize=(12,10))

for i in idx:
  cnt += 1
  plt.subplot(rows, cols, cnt)
  tmp = str(i) + ' ' +str(class_names[train_labels[i]])
  plt.title(tmp)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[i], cmap='Greys')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-65017a7b8947> in <module>()
#       2
#       3 rows, cols = 5,6
# ----> 4 idx = sorted(sample(range(len(train_images)), rows * cols)) #출력할 첨자 선정
#       5 print(idx)
#       6
#
# NameError: name 'train_images' is not defined

# %%
#fashion MNIST 분류 모델 학습 결과 시각화
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8a3d44d789b6> in <module>()
#       4
#       5 plt.subplot(1,2,1)
# ----> 6 plt.plot(history.history['loss'], 'b-', label='loss')
#       7 plt.plot(history.history['val_loss'], 'r--', label='val_loss')
#       8 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %%
predictions_array = [.1,.15,.2,.05,.5]
predicted_label = np.argmax(predictions_array)
true_label = 2;

thisplot = plt.bar(range(5), predictions_array, color="#999999")
thisplot[0].set_color('yellow')
thisplot[predicted_label].set_color('red')
thisplot[true_label].set_color(blue)

plt.ylim([0,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60a3020f503a> in <module>()
#       1 predictions_array = [.1,.15,.2,.05,.5]
# ----> 2 predicted_label = np.argmax(predictions_array)
#       3 true_label = 2;
#       4
#       5 thisplot = plt.bar(range(5), predictions_array, color="#999999")
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import matplot.pylab as plt

plt.rcParams['font.family'] = "Malgun Gothic"
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

y=[2,3,1]
x=np.arange(len(y))
xlabel=['가','나','다']
plt.title("Bar Chart")
plt.bar(x,y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-42caf8e1c789> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import matplot.pylab as plt
#       3
#       4 plt.rcParams['font.family'] = "Malgun Gothic"
#       5 plt.rcParams['font.size'] = 12
#
# ModuleNotFoundError: No module named 'matplot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def plot_image(i,predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.xticks([])
  plt.yticks([])

  predicted_label = np.argmax(predictions_array)

  if predicted_label == true_label:
    color = 'blue'
  else:
    color='red'

  maxprob = np.max(predictions_array)
  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label], 100* maxprob, class_names[true_label]), color = color)

  plt.imshow(img, cmap = plt.cm.binary)

# %%
def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.xticks([])
  plt.yticks([])
  plt.ylim([0,1])
  thisplot = plt.bar(range(10), predictions_array, color="#447777")

  predicted_label = np.argmax(predictions_array)
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

  x = np.arange(10)
  xlabel = np.arange(10)
  plt.xticks(x,xlabel)

# %%
predictions = model.predict(test_images)

i=0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot.image(i,predictions, test_labels, test_images)
plt,subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f083c263dc57> in <module>()
# ----> 1 predictions = model.predict(test_images)
#       2
#       3 i=0
#       4 plt.figure(figsize=(6,3))
#       5 plt.subplot(1,2,1)
#
# NameError: name 'model' is not defined

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))

for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)

  plt.tight_layout()
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2294800c62fc> in <module>()
#       6 for i in range(num_images):
#       7   plt.subplot(num_rows, 2*num_cols, 2*i+1)
# ----> 8   plot_image(i, predictions, test_labels, test_images)
#       9   plt.subplot(num_rows, 2*num_cols, 2*i+2)
#      10   plot_value_array(i, predictions, test_labels)
#
# NameError: name 'predictions' is not defined

# %%
num_rows = 5
num_cols=3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))

for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-87cf60289ad9> in <module>()
#       6 for i in range(num_images):
#       7   plt.subplot(num_rows, 2*num_cols, 2*i+1)
# ----> 8   plot_image(i, predictions, test_labels, test_images)
#       9   plt.subplot(num_rows, 2*num_cols, 2*i+2)
#      10   plot_value_array(i, predictions, test_labels)
#
# NameError: name 'predictions' is not defined

# %%
pred_result = model.predict(test_images)
pred_labels = tf.argmax(pred_result, axis=1)

mispred = []
for i in range(0, len(test_labels[i])):
  if pred_labels[i] != test_labels[i]:
    mispred.append(i)
print('정답이 틀린 수', len(mispred))

samples = sorted(sample(mispred,30))
print(samples)

count=0
rows, cols = 6,5
plt.figure(figsize=(12,10))
for i in samples:
  count +=1
  plt.subplot(rows, cols, count)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(test_images[i],reshape(28,28), cmap='Greys', interpolation='nearest')
  tmp = str(class_names[test_labels[i]]) + ", pred:" + str(class_names[pred_labels[i]])
  plt.title(tmp)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-170d95ba8f3f> in <module>()
# ----> 1 pred_result = model.predict(test_images)
#       2 pred_labels = tf.argmax(pred_result, axis=1)
#       3
#       4 mispred = []
#       5 for i in range(0, len(test_labels[i])):
#
# NameError: name 'model' is not defined

# %%
#틀린 것 30개 그리기
count=0
rows, cols = 10,6
plt.figure(figsize=(22, 30))

for i in samples:
  count +=1
  plt.subplot(rows, cols, count)
  plot_image(i, pred_result, test_labels, test_images)
  count += 1
  plt.subplot(rows, cols, count)
  plot_value_array(i, pred_result, test_labels)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b1874639dadd> in <module>()
#       4 plt.figure(figsize=(22, 30))
#       5
# ----> 6 for i in samples:
#       7   count +=1
#       8   plt.subplot(rows, cols, count)
#
# NameError: name 'samples' is not defined

# %%
import tensorflow as tf

def get_loss(label, prob):

  cce = tf.keras.losses.SparseCategoricalCrossentropy()
  loss = cce(tf.convert_to_tensor(label), tf.convert_to_tensor(prob))
  return loss

print('COE: ', get_loss([2],[[0.2,.1,.3,.4]]).numpy())
print('COE: ', get_loss(2,[[0.2,.1,.3,.4]]).numpy())
print('COE: ', get_loss(3,[[0.2,.1,.3,.4]]).numpy())
print('COE: ', get_loss(5,[[3.579432e-07, 1.6668336e-09, 1.2257135e-07, 3.7462252e-07, 4.4686758e-06, 6.8782866e-02, 1.0355227e-06, 5.1593245e-04, 2.1532403e-09,9.3069482e-01]]).numpy())
print('COE: ', get_loss(9,[[3.579432e-07, 1.6668336e-09, 1.2257135e-07, 3.7462252e-07, 4.4686758e-06, 6.8782866e-02, 1.0355227e-06, 5.1593245e-04, 2.1532403e-09,9.3069482e-01]]).numpy())
# Out:
# COE:  1.2039728
# COE:  1.2039728
# COE:  0.91629076
# COE:  2.6768007
# COE:  0.07182401

# %%
def get_loss(label, prob):
  cce = tf.keras,losses.SparseCategoricalCrossentropy()
  loss = cce(tf.convert_to_tensor(label), tf.convert_to_tensor(prob))
  return loss

  pred_labels = model.predict(test_images)


cces=[]
for i in range(len(test_images)):
  cces.append(get_loss(test_labels[i], pred_labels[i]).numpy())

print(len(cces))
print(cces[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-540c63538768> in <module>()
#       8
#       9 cces=[]
# ---> 10 for i in range(len(test_images)):
#      11   cces.append(get_loss(test_labels[i], pred_labels[i]).numpy())
#      12
#
# NameError: name 'test_images' is not defined

# %%
import numpy as np
a = np.random.randint (0,20,10)

a

np.argsort(a) #오름차순 (순방향) 정렬 첨자값

np.argsort(-a)

print(a[np.argsort(a)[-1]])
print(a[np.argsort(a)[0]])

print(a[np.argsort(a)[0]])
print(a[np.argsort(-a)[-1]])

for _ in range(len(a)):
  print(a[np.argsort(a)[_]], end = ' ')

for _ in range(len(a)):
  print(a[np.argsort(-a)[_]], end = ' ')
# Out:
# 18
# 0
# 0
# 0
# 0 8 8 9 10 11 11 16 17 18 18 17 16 11 11 10 9 8 8 0

# %%
def plot_value_cce_array(i,predictions_array, true_label):
  plot_value_cce_array(i,predictions_array, true_label)
  plt.title('CCE:' +str(get_loss(true_label[i], predictions_array[i]).numpy()))

arycces = np.array(cces)
lst_arg = np.argsort(-arycces)

for i in range(20):
  print(cces[lst_arg[i]], end = '')
print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-c14fccd4b8bd> in <module>()
#       7
#       8 for i in range(20):
# ----> 9   print(cces[lst_arg[i]], end = '')
#      10 print()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
count = 0
rows, cols = 10,6
plt.figure(figsize=(22,30))

for i in range(30):
  count += 1
  plt.subplot(rows, cols, count)
  plot_image (lst_arg[i],pred_result, test_labels, test_images)
  count+=1
  plt.subplot(rows, cols, count)
  plot_value_cce_array(lst_arg[i],pred_result, test_labels)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-82832b2cb3dd> in <module>()
#       1 count = 0
#       2 rows, cols = 10,6
# ----> 3 plt.figure(figsize=(22,30))
#       4
#       5 for i in range(30):
#
# NameError: name 'plt' is not defined

# %%
def plot_value_cce_array(i, predictions_array, true_label):
  plot_value_cce_array(i,predictions_array, true_label)
  plt.title("CCE: " + str(get_loss(true_label[i], predictions_array[i]).numpy()))

# %%
arycces = np.array(cces)
lst_arg = np.argsort(-arycces)

for i in range(20):
  print(cces[lst_arg[i]], end= '')
  print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-2302fe81ae15> in <module>()
#       3
#       4 for i in range(20):
# ----> 5   print(cces[lst_arg[i]], end= '')
#       6   print()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
