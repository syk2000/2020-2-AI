# %% [markdown]
# 자연수와 자연수의 지수 승

# %%
import tensorflow as tf
import numpy as np
np.e
# Out:
# 2.718281828459045

# %%
import numpy as np
import matplotlib.pylab as plt #pylab을 pyplot을 대체 가능

plt.figure(figsize=(6, 4))
x= np.linspace(-8,8,100)
plt.plot(x,np.exp(-x), 'b--.')
_=plt.plot(x,np.exp(x), 'r-.')

# %%
np.e
# Out:
# 2.718281828459045

# %%
#S자 곡선 sigmod 함수

import numpy as np
import matplotlib.pylab as pl #pylab을 pyplot을 대체 가능

def sigm_func(x):#sigmoid 함수
  return 1/(1 + np.exp(-x))
#시그모이드 함수 그리기
plt.figure(figsize=(8, 6))
x= np.linspace(-8,8,100)
plt.plot(x,np.exp(x), 'b--.')

# %%
#RELU 함수 0,음수면 그래프는 0 양수면 x

import numpy as np
import matplotlib.pylab as pl #pylab을 pyplot을 대체 가능

def relu_func(x):#sigmoid 함수
  return np.maximum(0,x)
  #return (x>0)*x #same

#Relu 함수 그리기
plt.figure(figsize=(8, 6))
x= np.linspace(-8,8,100)
plt.plot(x, relu_func(x))

# %%
#시그모이드 Relu 함께 그리기

import numpy as np
import matplotlib.pylab as pl #pylab을 pyplot을 대체 가능

#Relu(Rectfied Linear unit) 정류된 선형유닛 함수

def relu_func(x):#sigmoid 함수
  return np.maximum(0,x)
  #return (x>0)*x #same
  
def sigm_func(x):#sigmoid 함수
  return 1/(1 + np.exp(-x))

  #그래프 그리기
plt.figure(figsize=(8, 6))
x=np.linspace(-4,4,100)
y=np.linspace(-0.2,2,100)

plt.plot(x, relu_func(x), linestyle=':', label="ReLU")
plt.plot(x, sigm_func(x), linestyle='--', label="sigmoid")
plt.legend(loc='upper left')

# %%
import numpy as np
import matplotlib.pylab as pl #pylab을 pyplot을 대체 가능

def identity_func(x): #항등함수
  return x

def linear_func(x): #1차 함수
  return 1.5*x+1 #a 기울기(1.5), y절편b(1) 조정가능

def tanh_func(x): # TanH 함수
  return np.tanh(x)


def relu_func(x):#sigmoid 함수
  return np.maximum(0,x)
  #return (x>0)*x #same
  
def sigm_func(x):#sigmoid 함수
  return 1/(1 + np.exp(-x))

#그래프 그리기
plt.figure(figsize=(12,8))
x=np.linspace(-2,4,100)

plt.plot(x, identity_func(x), linestyle='--', label="identity")
plt.plot(x, linear_func(x), linestyle=':', label="linear")
plt.plot(x, tanh_func(x), linestyle='-', label="tanh")
plt.plot(x, relu_func(x), linestyle='-', label="ReLU")
plt.plot(x, sigm_func(x), linestyle='--', label="sigmoid")
plt.legend(loc='upper left')

# %% [markdown]
# 인공 신경망 행렬 연산 코드(매우 중요)

# %%
x=[[1,2]]
w=[[1,2,3],[4,5,6]]

y= tf.matmul(x,w)
y.numpy()
# Out:
# array([[ 9, 12, 15]], dtype=int32)

# %%
x=[[6,5],[4,7],[5,6],[6,7]]
w=[[1,2,3],[4,5,6]]

y= tf.matmul(x,w)
y.numpy()
# Out:
# array([[26, 37, 48],
#        [32, 43, 54],
#        [29, 40, 51],
#        [34, 47, 60]], dtype=int32)

# %%
w=[[1,4],[2,5],[3,6]]
x=[[6,4,5,6],[5,7,6,7]]

y= tf.matmul(w,x)
y.numpy()
# Out:
# array([[26, 32, 29, 34],
#        [37, 43, 40, 47],
#        [48, 54, 51, 60]], dtype=int32)

# %% [markdown]
# AND 게이트 구현
# 입력:2개
# 출력:1개
#
# 구중치 2개 편향1개를 정하는 것은 딥러닝이 해야할 것이다.

# %%
#tf.keras를 이용한 AND 네트워크 계산
import numpy as np

x=np.array([[1,1],[1,0],[0,1],[0,0]])
y= np.array([[1],[0],[0],[0]])

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(units=1,activation='sigmoid',input_shape=(2,)),
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3), loss='mse')
                                                #가중치   #편향
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x,y,epochs=400, batch_size=1)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2923
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2486
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2171
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1928
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1792
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1700
# Epoch 7/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1629
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1582
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1537
# Epoch 10/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1502
# Epoch 11/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1464
# Epoch 12/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1430
# ...

# %%
#3.34 2-레이어 XOR 네트워크의 loss 변화를 선 그래프로 표시
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model.predict(x)
# Out:
# array([[0.85709715],
#        [0.11935294],
#        [0.11912322],
#        [0.00304648]], dtype=float32)

# %%
#가중치와 편향 값 알아보기

for weight in model.weights:
  print(weight)
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[3.7921457],
#        [3.7899582]], dtype=float32)>
# <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-5.7907176], dtype=float32)>

# %%
model.weights[0]
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[3.7921457],
#        [3.7899582]], dtype=float32)>

# %%
model.weights[1]
# Out:
# <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-5.7907176], dtype=float32)>

# %%
#OR 게이트 구현
#tf.keras를 이용한 OR 네트워크 계산
import numpy as np

x=np.array([[1,1],[1,0],[0,1],[0,0]])
y= np.array([[1],[1],[1],[0]]) #AND 와 차이점 y의 값만 바뀌면 된다.

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(units=1,activation='sigmoid',input_shape=(2,)),
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3), loss='mse')
                                                #가중치   #편향
model.summary()

history = model.fit(x,y,epochs=400, batch_size=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1197
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1156
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1118
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1086
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1056
# Epoch 6/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 7/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1006
# Epoch 8/400
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model.predict(x)
# Out:
# array([[0.9991373 ],
#        [0.9262387 ],
#        [0.9263972 ],
#        [0.12008181]], dtype=float32)

# %%
for weight in model.weights:
  print(weight)
# Out:
# <tf.Variable 'dense_2/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[4.521954],
#        [4.524276]], dtype=float32)>
# <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([-1.991656], dtype=float32)>

# %%
#Sequential 모델
#DENSE층

x=np.array([[1,1],[1,0],[0,1],[0,0]])
y=np.array([[0],[1],[1],[0]])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=2, activation='sigmoid', input_shape(2,)), #, input_shape(2,)에서 오류가 난다 가중치 
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# %%
#3.27 tf.keras 를 이용한 xor 네트워크계산
import tensorflow as tf
import numpy as np

x= np.array([[1,1],[1,0],[0,1],[0,0]])
y= np.array([[0],[1],[1],[0]])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=2, activation='sigmoid', input_shape(2,)),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3),loss='mse')
model.summary()

#3.29 tf.keras를 이용한 XOR의 네트워크 학습
history = model.fit(x,y,epochs=2000, batch_size=1)

#3.39 tf.keras를 이용한 xor네트워크 평가
print(model.predict(x))

#3.30 xor네트워크의 가중치와 편향 확인
for weight in model.weights:
  print(weight)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-b3920a63711a> in <module>()
#      12
#      13 model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.3),loss='mse')
# ---> 14 model.summary()
#      15
#      16 #3.29 tf.keras를 이용한 XOR의 네트워크 학습
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in summary(self, line_length, positions, print_fn)
#    2349     """
#    2350     if not self.built:
# -> 2351       raise ValueError('This model has not yet been built. '
#    2352                        'Build the model first by calling `build()` or calling '
#    2353                        '`fit()` with some data, or specify '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data, or specify an `input_shape` argument in the first layer(s) for automatic build.
