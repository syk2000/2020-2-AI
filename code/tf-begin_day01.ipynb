# %% [markdown]
# #설명을 쓸수 있는 텍스트 코랩 start
# #shift+enter는 자동을 실행 = 컴파일과 같음

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
a=[2,3,4]
a
# Out:
# [2, 3, 4]

# %%
s = 'hellow, tesorflow'
s
# Out:
# 'hellow, tesorflow'

# %%
s
# Out:
# 'hellow, tesorflow'

# %%
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ea3e0efc71b0> in <module>()
#       2 import tensorflow as tf
#       3 hello = tf.constant('Hello Wolrd')
# ----> 4 sess = tf.Session()#반드시 1.대 버전을 이용하면 이것을 만들어야 한다
#       5 print(sess.run(hello))
#       6 sess.close()
#
# AttributeError: module 'tensorflow' has no attribute 'Session'
